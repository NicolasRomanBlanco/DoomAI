# %%
# !pip install vizdoom
# !pip install gym==0.21
# !cd github & git clone https://github.com/Farama-Foundation/ViZDoom
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install stable-baselines3[extra]==1.6.0
# Out:
# Collecting vizdoom
#   Downloading vizdoom-1.2.3-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in c:\users\nicol\onedrive\desktop\nico\estudios\pythonvenv\jupyter_playground\lib\site-packages (from vizdoom) (1.26.4)
# Requirement already satisfied: gymnasium>=0.28.0 in c:\users\nicol\onedrive\desktop\nico\estudios\pythonvenv\jupyter_playground\lib\site-packages (from vizdoom) (0.29.1)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\nicol\onedrive\desktop\nico\estudios\pythonvenv\jupyter_playground\lib\site-packages (from vizdoom) (2.5.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\nicol\onedrive\desktop\nico\estudios\pythonvenv\jupyter_playground\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\nicol\onedrive\desktop\nico\estudios\pythonvenv\jupyter_playground\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\nicol\onedrive\desktop\nico\estudios\pythonvenv\jupyter_playground\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\nicol\onedrive\desktop\nico\estudios\pythonvenv\jupyter_playground\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (7.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\nicol\onedrive\desktop\nico\estudios\pythonvenv\jupyter_playground\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium>=0.28.0->vizdoom) (3.17.0)
# Downloading vizdoom-1.2.3-cp39-cp39-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.5 MB 11.4 MB/s eta 0:00:02
#    -- ------------------------------------- 1.0/15.5 MB 22.5 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/15.5 MB 22.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 2.1/15.5 MB 13.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/15.5 MB 13.3 MB/s eta 0:00:02
#    -------- ------------------------------- 3.1/15.5 MB 11.8 MB/s eta 0:00:02
#    -------- ------------------------------- 3.1/15.5 MB 11.8 MB/s eta 0:00:02
#    -------- ------------------------------- 3.1/15.5 MB 11.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/15.5 MB 10.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/15.5 MB 10.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/15.5 MB 10.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/15.5 MB 10.7 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.5 MB 8.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.5 MB 8.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.5 MB 8.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.5 MB 8.8 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.5 MB 8.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.3/15.5 MB 7.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.3/15.5 MB 7.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.3/15.5 MB 7.6 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/15.5 MB 7.7 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/15.5 MB 7.7 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/15.5 MB 7.7 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/15.5 MB 7.7 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/15.5 MB 7.7 MB/s eta 0:00:02
#    --------------------- ------------------ 8.4/15.5 MB 7.1 MB/s eta 0:00:02
#    --------------------- ------------------ 8.4/15.5 MB 7.1 MB/s eta 0:00:02
#    ------------------------ --------------- 9.4/15.5 MB 7.3 MB/s eta 0:00:01
#    ------------------------ --------------- 9.4/15.5 MB 7.3 MB/s eta 0:00:01
#    ------------------------ --------------- 9.4/15.5 MB 7.3 MB/s eta 0:00:01
#    ------------------------ --------------- 9.4/15.5 MB 7.3 MB/s eta 0:00:01
#    --------------------------- ------------ 10.5/15.5 MB 7.1 MB/s eta 0:00:01
#    --------------------------- ------------ 10.5/15.5 MB 7.1 MB/s eta 0:00:01
#    --------------------------- ------------ 10.5/15.5 MB 7.1 MB/s eta 0:00:01
#    --------------------------- ------------ 10.5/15.5 MB 7.1 MB/s eta 0:00:01
#    --------------------------- ------------ 10.5/15.5 MB 7.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.5 MB 6.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.5 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.5 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.6/15.5 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 4.5 MB/s eta 0:00:00
# Installing collected packages: vizdoom
# Successfully installed vizdoom-1.2.3

# %%
# Import vizdoom for game env
from vizdoom import *
# Import random for action sampling
import random
# Import time for sleeping
import time
# Import numpy for identity matrix
import numpy as np
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces
from gym.spaces import Discrete, Box 
# Import opencv
import cv2
# Import Environment checker
from stable_baselines3.common import env_checker
# Import os for file nav
import os
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback
# Import PPO for training
from stable_baselines3 import PPO
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Create ViZDoom OpenAI Gym environment
class VizDoomGym(Env):
    # Function that is called when whe start the env
    def __init__(self, render=False):
        # Inherit from Env
        super().__init__()
        # Setup the game
        self.game = DoomGame()
        self.game.load_config('github/ViZDoom/scenarios/basic.cfg')

        # Render frame Logic
        if render == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
        
        # Start the game
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8)
        self.action_space = Discrete(3)
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
        
    # Define how to render the game or environment
    def render(self):
        pass
        
    # What happens when we start a new game
    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
        
    # Grayscale the game frame and resize it
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
        
    # Close doen the game
    def close(self):
        self.game.close()

class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
            
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
                                      
        return True
        
CHECKPOINT_DIR = './train/train_basic'
LOG_DIR = './logs/log_basic'

# Setup model saving callback
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# Non render environment
env = VizDoomGym()
# Create the model
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=2048)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
# Train the model
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/log_basic\PPO_9
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.8     |
# |    ep_rew_mean     | -94.2    |
# | time/              |          |
# |    fps             | 120      |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | -68.3        |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 2            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0069714384 |
# |    clip_fraction        | 0.231        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -9.68e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.08e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.00709      |
# |    value_loss           | 2.29e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.5        |
# |    ep_rew_mean          | -17.8       |
# | time/                   |             |
# |    fps                  | 103         |
# |    iterations           | 3           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010215338 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0746      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.45e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00643    |
# |    value_loss           | 3.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.9        |
# |    ep_rew_mean          | -21.9       |
# | time/                   |             |
# |    fps                  | 101         |
# |    iterations           | 4           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017172012 |
# |    clip_fraction        | 0.262       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.356       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.87e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.000535    |
# |    value_loss           | 3.48e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.8        |
# |    ep_rew_mean          | -8.28       |
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 5           |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.025561836 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.87e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.000387    |
# |    value_loss           | 4.79e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.5        |
# |    ep_rew_mean          | 5.86        |
# | time/                   |             |
# |    fps                  | 98          |
# |    iterations           | 6           |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015858911 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.05e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.000465    |
# |    value_loss           | 4.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.9        |
# |    ep_rew_mean          | -18.5       |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 7           |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023905654 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.34e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00491     |
# |    value_loss           | 3.57e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | 23.2        |
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 8           |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.016449964 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.79e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 3.57e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.5        |
# |    ep_rew_mean          | 8.41        |
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 9           |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.028706502 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.43e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0123      |
# |    value_loss           | 3.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.9        |
# |    ep_rew_mean          | -11.1       |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 10          |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018869286 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 996         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0212      |
# |    value_loss           | 2.51e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.7        |
# |    ep_rew_mean          | 8.4         |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 11          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.018777791 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.975      |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.31e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00455     |
# |    value_loss           | 3.15e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13         |
# |    ep_rew_mean          | 36.6       |
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 12         |
# |    time_elapsed         | 253        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.02388052 |
# |    clip_fraction        | 0.336      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.945     |
# |    explained_variance   | 0.535      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.3e+03    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.0127     |
# |    value_loss           | 3.47e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.5        |
# |    ep_rew_mean          | 31.8        |
# | time/                   |             |
# |    fps                  | 97          |
# |    iterations           | 13          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.025094511 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.79e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00152     |
# |    value_loss           | 3.65e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.3         |
# |    ep_rew_mean          | 47           |
# | time/                   |              |
# |    fps                  | 97           |
# |    iterations           | 14           |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0137454495 |
# |    clip_fraction        | 0.229        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.887       |
# |    explained_variance   | 0.695        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.53e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00301     |
# |    value_loss           | 2.67e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.36        |
# |    ep_rew_mean          | 67.8        |
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 15          |
# |    time_elapsed         | 317         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.028269686 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.859      |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.34e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.00164     |
# |    value_loss           | 2.94e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.11       |
# |    ep_rew_mean          | 57.4       |
# | time/                   |            |
# |    fps                  | 96         |
# |    iterations           | 16         |
# |    time_elapsed         | 340        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.06688605 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.75      |
# |    explained_variance   | 0.394      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 700        |
# |    n_updates            | 150        |
# |    policy_gradient_loss | 0.0315     |
# |    value_loss           | 1.47e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.36       |
# |    ep_rew_mean          | 63.5       |
# | time/                   |            |
# |    fps                  | 95         |
# |    iterations           | 17         |
# |    time_elapsed         | 364        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.02274727 |
# |    clip_fraction        | 0.338      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.754     |
# |    explained_variance   | 0.555      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 315        |
# |    n_updates            | 160        |
# |    policy_gradient_loss | 0.0229     |
# |    value_loss           | 1.11e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 44          |
# | time/                   |             |
# |    fps                  | 95          |
# |    iterations           | 18          |
# |    time_elapsed         | 386         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.040126167 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.77       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 447         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.0144      |
# |    value_loss           | 996         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.61        |
# |    ep_rew_mean          | 68.3        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 19          |
# |    time_elapsed         | 410         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.027404523 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 441         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00273    |
# |    value_loss           | 1.18e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.98       |
# |    ep_rew_mean          | 71         |
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 20         |
# |    time_elapsed         | 432        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.01955911 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.648     |
# |    explained_variance   | 0.48       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 344        |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.0165     |
# |    value_loss           | 695        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.12      |
# |    ep_rew_mean          | 76.4      |
# | time/                   |           |
# |    fps                  | 94        |
# |    iterations           | 21        |
# |    time_elapsed         | 456       |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0492599 |
# |    clip_fraction        | 0.259     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.659    |
# |    explained_variance   | 0.63      |
# |    learning_rate        | 0.0001    |
# |    loss                 | 167       |
# |    n_updates            | 200       |
# |    policy_gradient_loss | 0.00382   |
# |    value_loss           | 538       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.49        |
# |    ep_rew_mean          | 80          |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 22          |
# |    time_elapsed         | 480         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.056796297 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 105         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0052      |
# |    value_loss           | 305         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.63        |
# |    ep_rew_mean          | 83.3        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 23          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.046143968 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.447      |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 43.7        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00389     |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.44        |
# |    ep_rew_mean          | 84.5        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 24          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.051742136 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.35       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 63.1        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0109      |
# |    value_loss           | 141         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4.87      |
# |    ep_rew_mean          | 82.4      |
# | time/                   |           |
# |    fps                  | 92        |
# |    iterations           | 25        |
# |    time_elapsed         | 550       |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0345776 |
# |    clip_fraction        | 0.173     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.341    |
# |    explained_variance   | 0.662     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 66.5      |
# |    n_updates            | 240       |
# |    policy_gradient_loss | 0.0278    |
# |    value_loss           | 134       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.22        |
# |    ep_rew_mean          | 85.9        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 26          |
# |    time_elapsed         | 574         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.025786381 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.242      |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 70.2        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 173         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.3         |
# |    ep_rew_mean          | 85          |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 27          |
# |    time_elapsed         | 598         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.047492906 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.274      |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.1        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0255      |
# |    value_loss           | 70.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.17        |
# |    ep_rew_mean          | 85.8        |
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 28          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.026827468 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.196      |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.16        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00657     |
# |    value_loss           | 70.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.21        |
# |    ep_rew_mean          | 85.6        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 29          |
# |    time_elapsed         | 648         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.042969503 |
# |    clip_fraction        | 0.0983      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.165      |
# |    explained_variance   | 0.673       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 33.7        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0306      |
# |    value_loss           | 59.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.44        |
# |    ep_rew_mean          | 84.9        |
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 30          |
# |    time_elapsed         | 673         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009874576 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.136      |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 18.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0115      |
# |    value_loss           | 33.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.73        |
# |    ep_rew_mean          | 87.6        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 31          |
# |    time_elapsed         | 698         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.015773654 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.147      |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.21        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0212      |
# |    value_loss           | 14.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.67       |
# |    ep_rew_mean          | 87.9       |
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 32         |
# |    time_elapsed         | 723        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02784532 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.139     |
# |    explained_variance   | 0.717      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 12         |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0183     |
# |    value_loss           | 47.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.42       |
# |    ep_rew_mean          | 84.4       |
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 33         |
# |    time_elapsed         | 749        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.03791471 |
# |    clip_fraction        | 0.0637     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.123     |
# |    explained_variance   | 0.853      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 7.17       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.011      |
# |    value_loss           | 20.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.55       |
# |    ep_rew_mean          | 84         |
# | time/                   |            |
# |    fps                  | 90         |
# |    iterations           | 34         |
# |    time_elapsed         | 773        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.04684612 |
# |    clip_fraction        | 0.12       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.123     |
# |    explained_variance   | 0.538      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 57         |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.0137     |
# |    value_loss           | 108        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.62        |
# |    ep_rew_mean          | 84.4        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 35          |
# |    time_elapsed         | 795         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.039093655 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.111      |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 88.1        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00582     |
# |    value_loss           | 54.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.78        |
# |    ep_rew_mean          | 87.6        |
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 36          |
# |    time_elapsed         | 818         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.042869043 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.127      |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 5.08        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00604     |
# |    value_loss           | 55.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.88        |
# |    ep_rew_mean          | 87.2        |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 37          |
# |    time_elapsed         | 844         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014951832 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.145      |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11          |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00648     |
# |    value_loss           | 81.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.43        |
# |    ep_rew_mean          | 85          |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 38          |
# |    time_elapsed         | 868         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.043916684 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.117      |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.04        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00599     |
# |    value_loss           | 44.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.84       |
# |    ep_rew_mean          | 83         |
# | time/                   |            |
# |    fps                  | 89         |
# |    iterations           | 39         |
# |    time_elapsed         | 892        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03564018 |
# |    clip_fraction        | 0.0628     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.121     |
# |    explained_variance   | 0.662      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 3.8        |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.00882    |
# |    value_loss           | 50.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.82        |
# |    ep_rew_mean          | 87.2        |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 40          |
# |    time_elapsed         | 917         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.018822096 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.119      |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.98        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0253      |
# |    value_loss           | 26          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4          |
# |    ep_rew_mean          | 86.7       |
# | time/                   |            |
# |    fps                  | 89         |
# |    iterations           | 41         |
# |    time_elapsed         | 942        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02131017 |
# |    clip_fraction        | 0.0655     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.111     |
# |    explained_variance   | 0.761      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 9.53       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.0159     |
# |    value_loss           | 36.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.98        |
# |    ep_rew_mean          | 86.6        |
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 42          |
# |    time_elapsed         | 966         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.030571489 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0915     |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 21.8        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 38.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.93        |
# |    ep_rew_mean          | 87          |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 43          |
# |    time_elapsed         | 989         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009039847 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.104      |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.28        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0197      |
# |    value_loss           | 22.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.65       |
# |    ep_rew_mean          | 67.2       |
# | time/                   |            |
# |    fps                  | 89         |
# |    iterations           | 44         |
# |    time_elapsed         | 1011       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.06192018 |
# |    clip_fraction        | 0.0933     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0995    |
# |    explained_variance   | 0.687      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 27         |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.00985    |
# |    value_loss           | 49.1       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.6       |
# |    ep_rew_mean          | 88.4      |
# | time/                   |           |
# |    fps                  | 89        |
# |    iterations           | 45        |
# |    time_elapsed         | 1035      |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.4826259 |
# |    clip_fraction        | 0.182     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.124    |
# |    explained_variance   | 0.641     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 17.2      |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0255   |
# |    value_loss           | 127       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.57        |
# |    ep_rew_mean          | 88.7        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 46          |
# |    time_elapsed         | 1058        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.029325377 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0815     |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11          |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0206      |
# |    value_loss           | 30.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.02        |
# |    ep_rew_mean          | 86.8        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 47          |
# |    time_elapsed         | 1082        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011963498 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0809     |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 46          |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0122      |
# |    value_loss           | 35.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.55        |
# |    ep_rew_mean          | 88.6        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 48          |
# |    time_elapsed         | 1105        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.013015943 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0884     |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.28        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0288      |
# |    value_loss           | 8.76        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.66        |
# |    ep_rew_mean          | 87.8        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 49          |
# |    time_elapsed         | 1131        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.029006634 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0775     |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.01        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0124      |
# |    value_loss           | 7.14        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.04       |
# |    ep_rew_mean          | 86.5       |
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 50         |
# |    time_elapsed         | 1154       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.06999409 |
# |    clip_fraction        | 0.0693     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0542    |
# |    explained_variance   | 0.726      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 22.1       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.00209    |
# |    value_loss           | 42.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.04        |
# |    ep_rew_mean          | 86.8        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 51          |
# |    time_elapsed         | 1178        |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.023996262 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0808     |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.8        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.0228      |
# |    value_loss           | 22.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.62        |
# |    ep_rew_mean          | 88.4        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 52          |
# |    time_elapsed         | 1204        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009515225 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0668     |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 16.8        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.0111      |
# |    value_loss           | 18.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.53        |
# |    ep_rew_mean          | 88.7        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 53          |
# |    time_elapsed         | 1230        |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008876143 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0704     |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.28        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | 0.0181      |
# |    value_loss           | 17.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.84       |
# |    ep_rew_mean          | 87.1       |
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 54         |
# |    time_elapsed         | 1254       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.04254926 |
# |    clip_fraction        | 0.0581     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0629    |
# |    explained_variance   | 0.861      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 8.99       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0286     |
# |    value_loss           | 17         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.66        |
# |    ep_rew_mean          | 88          |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 55          |
# |    time_elapsed         | 1278        |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.097351745 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0498     |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.05        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00142    |
# |    value_loss           | 22.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.89       |
# |    ep_rew_mean          | 87.1       |
# | time/                   |            |
# |    fps                  | 88         |
# |    iterations           | 56         |
# |    time_elapsed         | 1302       |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.03676168 |
# |    clip_fraction        | 0.0579     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0569    |
# |    explained_variance   | 0.733      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 27.7       |
# |    n_updates            | 550        |
# |    policy_gradient_loss | 0.00713    |
# |    value_loss           | 33.2       |
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 model.learn(total_timesteps=1000000, callback=callback)
#
# File ~\OneDrive\Desktop\Nico\Estudios\PythonVenv\jupyter_playground\lib\site-packages\stable_baselines3\ppo\ppo.py:310, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     297 def learn(
#     298     self,
#     299     total_timesteps: int,
#    (...)
#     307     reset_num_timesteps: bool = True,
#     308 ) -> "PPO":
# --> 310     return super().learn(
#     311         total_timesteps=total_timesteps,
#     312         callback=callback,
#     313         log_interval=log_interval,
#     314         eval_env=eval_env,
#     315         eval_freq=eval_freq,
#     316         n_eval_episodes=n_eval_episodes,
#     317         tb_log_name=tb_log_name,
#     318         eval_log_path=eval_log_path,
#     319         reset_num_timesteps=reset_num_timesteps,
#     320     )
#
# File ~\OneDrive\Desktop\Nico\Estudios\PythonVenv\jupyter_playground\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:247, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     243 callback.on_training_start(locals(), globals())
#     245 while self.num_timesteps < total_timesteps:
# --> 247     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     249     if continue_training is False:
#     250         break
#
# File ~\OneDrive\Desktop\Nico\Estudios\PythonVenv\jupyter_playground\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:167, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     165     obs_tensor = obs_as_tensor(self._last_obs, self.device)
#     166     actions, values, log_probs = self.policy(obs_tensor)
# --> 167 actions = actions.cpu().numpy()
#     169 # Rescale and perform action
#     170 clipped_actions = actions
#
# KeyboardInterrupt:

# %%
# Reload from disc
model = PPO.load('./train/train_basic/best_model_150000')

# %%
# Create a rendered environment
env = VizDoomGym(render=True)

# %%
# Evaluate mean reward for 100 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=100)
# Out:
# C:\Users\nicol\OneDrive\Desktop\Nico\Estudios\PythonVenv\jupyter_playground\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
# Evaluate the total reward for 10 episodes
for episode in range(10):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.20)
        total_reward += reward
    print('Total reward for episode {} is {}'.format(episode, total_reward))
    time.sleep(2)
# Out:
# Total reward for episode 0 is 95.0
# Total reward for episode 1 is 95.0
# Total reward for episode 2 is 95.0
# Total reward for episode 3 is 87.0
# Total reward for episode 4 is 95.0
